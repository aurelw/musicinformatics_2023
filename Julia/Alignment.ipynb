# %%
import warnings

import partitura as pt
import os
from concurrent.futures import ProcessPoolExecutor

# Uncomment this line if the kernel keeps crashing
# See https://stackoverflow.com/a/53014308
# os.environ['KMP_DUPLICATE_LIB_OK']='True'

from typing import Union, List, Tuple, Dict, Any

import numpy as np
from fastdtw import fastdtw
from scipy.spatial import distance as sp_dist
from tqdm import tqdm

from challenge_utils import (
    load_dataset,
    compare_alignments,
    export_to_challenge,
)

warnings.filterwarnings(
    "ignore",
    category=UserWarning,
    module="partitura.*",
)

# %%
def compute_pianoroll_score(
    score_note_array: np.ndarray,
    time_div: Union[str, int] = "auto",
) -> (np.ndarray, np.ndarray):
    """
    Compute Piano Roll for the Score

    Parameters
    ----------
    score_note_array : structured array
        Structured array with note information for the score
    time_div : int or "auto"
       Resolution of the piano roll (how many "cells" per beat).

    Returns
    -------
    pianoroll : np.ndarray
       A 2D pianoroll where rows represent time steps (1 / time_div)
       and columns represent musical pitch
    idx : np.ndarray
       An array of indices of the notes in the spart

    Note: In this example, both `compute_pianoroll_score` and
    `compute_pianoroll_performance` are almost identical functions,
    but you can/should play with different settings/options/features
    """
    piano_roll, idx = pt.utils.music.compute_pianoroll(
        note_info=score_note_array,
        return_idxs=True,
        piano_range=True,  # Since we are using only piano music,
        time_div=time_div,
        binary=True,
        time_unit="beat",
    )

    return piano_roll.toarray().T, idx


def compute_pianoroll_performance(
    performance_note_array: np.ndarray,
    time_div: Union[str, int] = "auto",
) -> (np.ndarray, np.ndarray):
    """
    Compute Piano Roll for the Score

    Parameters
    ----------
    performance_note_array : structured array
       Structured array with performance information
    time_div : int or "auto"
       Resolution of the piano roll (how many "cells" per second).

    Returns
    -------
    pianoroll : np.ndarray
       A 2D pianoroll where rows represent time steps (1 / time_div)
       and columns represent musical pitch
    idx : np.ndarray
       An array of indices of the notes in the ppart

    Note: In this example, both `compute_pianoroll_score` and
    `compute_pianoroll_performance` are almost identical functions,
    but you can/should play with different settings/options/features
    """
    piano_roll, idx = pt.utils.music.compute_pianoroll(
        note_info=performance_note_array,
        return_idxs=True,
        piano_range=True,  # Since we are using only piano music,
        time_div=time_div,
        binary=True,
        time_unit="sec",
    )

    # Discard MIDI velocity
    piano_roll = piano_roll.toarray().T
    return piano_roll, idx

# %%
#### DYNAMIC TIME WARPING


def fast_dynamic_time_warping(
    X: np.ndarray,
    Y: np.ndarray,
    metric: str = "euclidean", 
) -> (np.ndarray, float):
    """
     Fast Dynamic Time Warping

    This is an approximate solution to dynamic time warping.

    Parameters
    ----------
    X : np.ndarray
    Y: np.ndarray
    metric : str
       The name of the metric to use

    Returns
    -------
    warping_path: np.ndarray
        The warping path for the best alignment
    dtwd : float
        The dynamic time warping distance of the alignment.
    """

    # Get distance measure from scipy dist

    if metric == "euclidean":
        # Use faster implementation
        dist = 2
    else:
        dist = getattr(sp_dist, metric)

    dtwd, warping_path = fastdtw(X, Y, dist=dist)
    #dtwd, warping_path = fastdtw(X, Y, radius=5, dist=dist)

    # Make path a numpy array
    warping_path = np.array(warping_path, dtype=int)
    return warping_path, dtwd

# %%
#### NOTEWISE ALIGNMENT


def greedy_note_alignment(
    warping_path: np.ndarray,
    idx1: np.ndarray,
    note_array1: np.ndarray,
    idx2: np.ndarray,
    note_array2: np.ndarray,
) -> List[dict]:
    """
    Greedily find and store possible note alignments

    Parameters
    ----------
    warping_path : numpy ndarray
        alignment sequence idx in stacked columns
    idx1: numpy ndarray
        pitch, start, and end coordinates of all notes in note_array1
    note_array1: numpy structured array
        note_array of sequence 1 (the score)
    idx2: numpy ndarray
        pitch, start, and end coordinates of all notes in note_array2
    note_array2: numpy structured array
        note_array of sequence 2 (the performance)

    Returns
    ----------
    note_alignment : list
        list of note alignment dictionaries

    """
    note_alignment = []
    used_notes1 = []
    used_notes2 = []
    
    coord_info1 = idx1
    if idx1.shape[1] == 3:
        # Assume that the first column contains the correct MIDI pitch
        coord_info1 = np.column_stack((idx1, idx1[:, 0]))

    coord_info2 = idx2

    if idx2.shape[1] == 3:
        # Assume that the first column contains the correct MIDI pitch
        coord_info2 = np.column_stack((idx2, idx2[:, 0]))
        
    # loop over all notes in sequence 1
    for note1, coord1 in zip(note_array1, coord_info1):
        note1_id = note1["id"]
        pc1, s1, e1, pitch1 = coord1
        
        # find the coordinates of the note in the warping_path
        idx_in_warping_path = np.all(
            [warping_path[:, 0] >= s1 - 2, warping_path[:, 0] <= s1 + 1], axis=0
        )

        range_in_sequence2 = warping_path[idx_in_warping_path, 1]
        max2 = np.max(range_in_sequence2)
        min2 = np.min(range_in_sequence2)

        # loop over all notes in sequence 2 and pick the notes with same pitch
        # and position
        for note2, coord2 in zip(note_array2, coord_info2):
            note2_id = note2["id"]
            pc2, s2, e2, pitch2 = coord2
            if note2_id not in used_notes2:
                if pitch2 == pitch1 and s2 <= max2 and e2 >= min2:
                    note_alignment.append(
                        {
                            "label": "match",
                            "score_id": note1_id,
                            "performance_id": str(note2_id),
                        }
                    )
                    used_notes2.append(str(note2_id))
                    used_notes1.append(note1_id)

        # check if a note has been found for the sequence 1 note,
        # otherwise add it as deletion
        if note1_id not in used_notes1:
            note_alignment.append({"label": "deletion", "score_id": note1_id})
            used_notes1.append(note1_id)

    # check again for all notes in sequence 2, if not used,
    # add them as insertions
    for note2 in note_array2:
        note2_id = note2["id"]
        if note2_id not in used_notes2:
            note_alignment.append(
                {
                    "label": "insertion",
                    "performance_id": str(note2_id),
                }
            )
            used_notes2.append(str(note2_id))

    return note_alignment

# %%
# 1. Load the data
dataset = load_dataset("trainingset")
# Lists to store results
alignments = []
evaluation = []
piece_names = []

for i, (piece_name, pdata) in enumerate(dataset.items()):
    piece_names.append(piece_name)
    performance_note_array, score_note_array, gt_alignment = pdata
    # 2. Compute the features (Adapt this part as needed!)
    score_features, score_idx = compute_pianoroll_score(
        score_note_array=score_note_array,
        time_div="8",
    )
    performance_features, performance_idx = compute_pianoroll_performance(
        performance_note_array=performance_note_array,
        time_div="8",
    )
    # 3. Compute the alignment (Adapt this part as needed!)
    warping_path, _ = fast_dynamic_time_warping(
        X=score_features,
        Y=performance_features,
        metric="sqeuclidean",
    )
    predicted_alignment = greedy_note_alignment(
        warping_path=warping_path,
        idx1=score_idx,
        note_array1=score_note_array,
        idx2=performance_idx,
        note_array2=performance_note_array,
    )
    # Compute evaluation (Do not change this)
    alignments.append(predicted_alignment)

    piece_eval = compare_alignments(
        prediction=predicted_alignment,
        ground_truth=gt_alignment,
    )

    print(
        f"{i+1}/{len(dataset)} {piece_name}: "
        f"F-score:{piece_eval[2]:.2f} "
        f"Precision:{piece_eval[0]:.2f} "
        f"Recall:{piece_eval[1]:.2f}"
    )

    evaluation.append(piece_eval)

# compute mean evaluation
mean_eval = np.mean(evaluation, 0)

print(
    "\n\nAverage Performance over the dataset\n"
    f"F-score:{mean_eval[2]:.2f}\t"
    f"Precision:{mean_eval[0]:.2f}\t",
    f"Recall:{mean_eval[1]:.2f}",
)
# Out:
# 1/88 Chopin_op10_no3_p01: F-score:0.95 Precision:0.94 Recall:0.97
# 2/88 Chopin_op10_no3_p02: F-score:0.94 Precision:0.92 Recall:0.96
# 3/88 Chopin_op10_no3_p03: F-score:0.95 Precision:0.94 Recall:0.97
# 4/88 Chopin_op10_no3_p04: F-score:0.98 Precision:0.97 Recall:0.98
# 5/88 Chopin_op10_no3_p05: F-score:1.00 Precision:1.00 Recall:1.00
# 6/88 Chopin_op10_no3_p06: F-score:0.91 Precision:0.88 Recall:0.93
# 7/88 Chopin_op10_no3_p07: F-score:0.93 Precision:0.91 Recall:0.95
# 8/88 Chopin_op10_no3_p08: F-score:0.95 Precision:0.94 Recall:0.96
# 9/88 Chopin_op10_no3_p09: F-score:0.97 Precision:0.96 Recall:0.98
# 10/88 Chopin_op10_no3_p10: F-score:0.93 Precision:0.91 Recall:0.94
# 11/88 Chopin_op10_no3_p11: F-score:1.00 Precision:1.00 Recall:1.00
# 12/88 Chopin_op10_no3_p12: F-score:0.94 Precision:0.92 Recall:0.95
# 13/88 Chopin_op10_no3_p13: F-score:0.95 Precision:0.94 Recall:0.97
# 14/88 Chopin_op10_no3_p14: F-score:0.87 Precision:0.83 Recall:0.90
# 15/88 Chopin_op10_no3_p15: F-score:0.99 Precision:0.98 Recall:0.99
# 16/88 Chopin_op10_no3_p16: F-score:0.98 Precision:0.97 Recall:0.98
# 17/88 Chopin_op10_no3_p17: F-score:0.93 Precision:0.92 Recall:0.95
# 18/88 Chopin_op10_no3_p18: F-score:0.93 Precision:0.92 Recall:0.95
# 19/88 Chopin_op10_no3_p19: F-score:0.96 Precision:0.95 Recall:0.97
# 20/88 Chopin_op10_no3_p20: F-score:0.97 Precision:0.95 Recall:0.98
# 21/88 Chopin_op10_no3_p21: F-score:0.96 Precision:0.95 Recall:0.98
# 22/88 Chopin_op10_no3_p22: F-score:0.92 Precision:0.90 Recall:0.94
# 23/88 Chopin_op38_p01: F-score:0.80 Precision:0.76 Recall:0.85
# 24/88 Chopin_op38_p02: F-score:0.80 Precision:0.76 Recall:0.85
# 25/88 Chopin_op38_p03: F-score:0.84 Precision:0.79 Recall:0.88
# 26/88 Chopin_op38_p04: F-score:0.82 Precision:0.77 Recall:0.86
# 27/88 Chopin_op38_p05: F-score:0.83 Precision:0.79 Recall:0.87
# 28/88 Chopin_op38_p06: F-score:0.83 Precision:0.78 Recall:0.87
# 29/88 Chopin_op38_p07: F-score:0.82 Precision:0.77 Recall:0.86
# 30/88 Chopin_op38_p08: F-score:0.85 Precision:0.80 Recall:0.89
# 31/88 Chopin_op38_p09: F-score:0.77 Precision:0.73 Recall:0.82
# 32/88 Chopin_op38_p10: F-score:0.81 Precision:0.77 Recall:0.86
# 33/88 Chopin_op38_p11: F-score:0.78 Precision:0.73 Recall:0.83
# 34/88 Chopin_op38_p12: F-score:0.84 Precision:0.79 Recall:0.88
# 35/88 Chopin_op38_p13: F-score:0.79 Precision:0.75 Recall:0.85
# 36/88 Chopin_op38_p14: F-score:0.79 Precision:0.74 Recall:0.84
# 37/88 Chopin_op38_p15: F-score:0.79 Precision:0.74 Recall:0.84
# 38/88 Chopin_op38_p16: F-score:0.83 Precision:0.79 Recall:0.87
# 39/88 Chopin_op38_p17: F-score:0.81 Precision:0.76 Recall:0.86
# 40/88 Chopin_op38_p18: F-score:0.74 Precision:0.69 Recall:0.79
# 41/88 Chopin_op38_p19: F-score:0.85 Precision:0.81 Recall:0.90
# 42/88 Chopin_op38_p20: F-score:0.78 Precision:0.74 Recall:0.83
# 43/88 Chopin_op38_p21: F-score:0.85 Precision:0.81 Recall:0.89
# 44/88 Chopin_op38_p22: F-score:0.84 Precision:0.80 Recall:0.89
# 45/88 Mozart_K331_1st-mov_p01: F-score:0.83 Precision:0.78 Recall:0.87
# 46/88 Mozart_K331_1st-mov_p02: F-score:0.83 Precision:0.79 Recall:0.88
# 47/88 Mozart_K331_1st-mov_p03: F-score:0.83 Precision:0.78 Recall:0.87
# 48/88 Mozart_K331_1st-mov_p04: F-score:0.86 Precision:0.82 Recall:0.90
# 49/88 Mozart_K331_1st-mov_p05: F-score:0.89 Precision:0.87 Recall:0.92
# 50/88 Mozart_K331_1st-mov_p06: F-score:0.83 Precision:0.79 Recall:0.88
# 51/88 Mozart_K331_1st-mov_p07: F-score:0.84 Precision:0.80 Recall:0.88
# 52/88 Mozart_K331_1st-mov_p08: F-score:0.83 Precision:0.79 Recall:0.88
# 53/88 Mozart_K331_1st-mov_p09: F-score:0.58 Precision:0.52 Recall:0.64
# 54/88 Mozart_K331_1st-mov_p10: F-score:0.84 Precision:0.81 Recall:0.89
# 55/88 Mozart_K331_1st-mov_p11: F-score:0.85 Precision:0.81 Recall:0.89
# 56/88 Mozart_K331_1st-mov_p12: F-score:0.85 Precision:0.81 Recall:0.89
# 57/88 Mozart_K331_1st-mov_p13: F-score:0.83 Precision:0.78 Recall:0.87
# 58/88 Mozart_K331_1st-mov_p14: F-score:0.87 Precision:0.83 Recall:0.90
# 59/88 Mozart_K331_1st-mov_p15: F-score:0.84 Precision:0.81 Recall:0.88
# 60/88 Mozart_K331_1st-mov_p16: F-score:0.85 Precision:0.81 Recall:0.89
# 61/88 Mozart_K331_1st-mov_p17: F-score:0.84 Precision:0.80 Recall:0.88
# 62/88 Mozart_K331_1st-mov_p18: F-score:0.62 Precision:0.57 Recall:0.69
# 63/88 Mozart_K331_1st-mov_p19: F-score:0.85 Precision:0.81 Recall:0.89
# 64/88 Mozart_K331_1st-mov_p20: F-score:0.83 Precision:0.79 Recall:0.88
# 65/88 Mozart_K331_1st-mov_p21: F-score:0.86 Precision:0.82 Recall:0.90
# 66/88 Mozart_K331_1st-mov_p22: F-score:0.89 Precision:0.87 Recall:0.92
# 67/88 Schubert_D783_no15_p01: F-score:0.87 Precision:0.84 Recall:0.91
# 68/88 Schubert_D783_no15_p02: F-score:0.90 Precision:0.87 Recall:0.93
# 69/88 Schubert_D783_no15_p03: F-score:0.87 Precision:0.84 Recall:0.91
# 70/88 Schubert_D783_no15_p04: F-score:0.92 Precision:0.90 Recall:0.95
# 71/88 Schubert_D783_no15_p05: F-score:0.76 Precision:0.70 Recall:0.82
# 72/88 Schubert_D783_no15_p06: F-score:0.90 Precision:0.87 Recall:0.92
# 73/88 Schubert_D783_no15_p07: F-score:0.81 Precision:0.77 Recall:0.86
# 74/88 Schubert_D783_no15_p08: F-score:0.85 Precision:0.81 Recall:0.89
# 75/88 Schubert_D783_no15_p09: F-score:0.85 Precision:0.81 Recall:0.89
# 76/88 Schubert_D783_no15_p10: F-score:0.90 Precision:0.88 Recall:0.93
# 77/88 Schubert_D783_no15_p11: F-score:0.81 Precision:0.77 Recall:0.84
# 78/88 Schubert_D783_no15_p12: F-score:0.89 Precision:0.86 Recall:0.92
# 79/88 Schubert_D783_no15_p13: F-score:0.87 Precision:0.84 Recall:0.91
# 80/88 Schubert_D783_no15_p14: F-score:0.82 Precision:0.78 Recall:0.87
# 81/88 Schubert_D783_no15_p15: F-score:0.91 Precision:0.89 Recall:0.94
# 82/88 Schubert_D783_no15_p16: F-score:0.81 Precision:0.77 Recall:0.86
# 83/88 Schubert_D783_no15_p17: F-score:0.85 Precision:0.81 Recall:0.89
# 84/88 Schubert_D783_no15_p18: F-score:0.78 Precision:0.73 Recall:0.84
# 85/88 Schubert_D783_no15_p19: F-score:0.79 Precision:0.75 Recall:0.85
# 86/88 Schubert_D783_no15_p20: F-score:0.87 Precision:0.83 Recall:0.91
# 87/88 Schubert_D783_no15_p21: F-score:0.81 Precision:0.77 Recall:0.87
# 88/88 Schubert_D783_no15_p22: F-score:0.85 Precision:0.80 Recall:0.89
#
#
# Average Performance over the dataset
# F-score:0.86	Precision:0.83	 Recall:0.90

# %%
# 1. Load the data
dataset = load_dataset("testset")
# Lists to store results
alignments = []
evaluation = []
piece_names = []

for i, (piece_name, pdata) in tqdm(enumerate(dataset.items())):
    piece_names.append(piece_name)
    performance_note_array, score_note_array, gt_alignment = pdata
    # 2. Compute the features (Adapt this part as needed!)
    score_features, score_idx = compute_pianoroll_score(
        score_note_array=score_note_array,
        time_div="8",
    )
    performance_features, performance_idx = compute_pianoroll_performance(
        performance_note_array=performance_note_array,
        time_div="8",
    )
    # 3. Compute the alignment (Adapt this part as needed!)
    warping_path, _ = fast_dynamic_time_warping(
        X=score_features,
        Y=performance_features,
        metric="sqeuclidean",
    )
    predicted_alignment = greedy_note_alignment(
        warping_path=warping_path,
        idx1=score_idx,
        note_array1=score_note_array,
        idx2=performance_idx,
        note_array2=performance_note_array,
    )
    # Compute evaluation (Do not change this)
    alignments.append(predicted_alignment)
# Out:
# 39it [2:30:04, 230.87s/it]

# %%
export_to_challenge(alignments, piece_names, out="results1")
